# %%
import folium
from folium.plugins import MiniMap

popuptext = '<b>Location</b>'

CR = folium.Map(location = (9.928739, -84.091048))
folium.Marker(location = [9.999527, -84.111328], popup = popuptext, icon = folium.Icon (color = "orange", icon = "ok-sign")).add_to(CR)

folium.Marker(location = [10.019857, -84.196719], popup = popuptext, icon = folium.Icon (color = "orange", icon = "ok-sign")).add_to(CR)

folium.Marker(location = [9.970759, -84.128874], popup = popuptext, icon = folium.Icon (color = "orange", icon = "ok-sign")).add_to(CR)

folium.Marker(location = [10.319793, -83.922820], popup = popuptext, icon = folium.Icon (color = "orange", icon = "ok-sign")).add_to(CR)

folium.Marker(location = [8.573854, -82.871576], popup = popuptext, icon = folium.Icon (color = "orange", icon = "ok-sign")).add_to(CR)

folium.Marker(location = [9.379535, -83.691097], popup = popuptext, icon = folium.Icon (color = "orange", icon = "ok-sign")).add_to(CR)

folium.Marker(location = [10.617686, -85.451997], popup = popuptext, icon = folium.Icon (color = "orange", icon = "ok-sign")).add_to(CR)

folium.Marker(location = [10.134691, -85.446985], popup = popuptext, icon = folium.Icon (color = "orange", icon = "ok-sign")).add_to(CR)

minimap = MiniMap(tile_layer = 'stamenterrain', posotion = 'bottomright')

CR.add_child(minimap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
