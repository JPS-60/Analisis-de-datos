# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

texto = open("nube.csv").read()
nube = WordCloud(width = 1000,
                 height = 1000).generate(texto)
plt.imshow(nube,interpolation = 'bilinear')

plt.axis("off")
plt.show()
